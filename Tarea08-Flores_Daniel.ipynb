# %% [markdown]
# # Escuela Politécnica Nacional
# ## Facultad de Ingeniería en Sistemas
# ## Materia: Métodos Numéricos
# ## Nombre: Daniel Ismael Flores Espín

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

x = np.array([4.0, 4.2, 4.5, 4.7, 5.1, 5.5, 5.9, 6.3, 6.8, 7.1])
y = np.array([102.56, 130.11, 113.18, 142.05, 167.53, 195.14, 224.87, 256.73, 299.50, 326.72])

def calcular_error(y_real, y_pred):
    return np.mean((y_real - y_pred) ** 2)

coef_1 = np.polyfit(x, y, 1)
pol_1 = np.poly1d(coef_1)
y_pred_1 = pol_1(x)
error_1 = calcular_error(y, y_pred_1)

coef_2 = np.polyfit(x, y, 2)
pol_2 = np.poly1d(coef_2)
y_pred_2 = pol_2(x)
error_2 = calcular_error(y, y_pred_2)

coef_3 = np.polyfit(x, y, 3)
pol_3 = np.poly1d(coef_3)
y_pred_3 = pol_3(x)
error_3 = calcular_error(y, y_pred_3)

def modelo_exp(x, a, b):
    return b * np.exp(a * x)

popt_exp, _ = curve_fit(modelo_exp, x, y, maxfev=10000)
y_pred_exp = modelo_exp(x, *popt_exp)
error_exp = calcular_error(y, y_pred_exp)

def modelo_pot(x, a, b):
    return b * x**a

popt_pot, _ = curve_fit(modelo_pot, x, y, maxfev=10000)
y_pred_pot = modelo_pot(x, *popt_pot)
error_pot = calcular_error(y, y_pred_pot)

print("Polinomio de grado 1:\n", pol_1)
print("Error: ", error_1, "\n")

print("Polinomio de grado 2:\n", pol_2)
print("Error: ", error_2, "\n")

print("Polinomio de grado 3:\n", pol_3)
print("Error: ", error_3, "\n")

print("Polinomio de la forma b * exp(a * x):")
print(f"a = {popt_exp[0]:.4f}, b = {popt_exp[1]:.4f}")
print("Error: ", error_exp, "\n")

print("Polinomio de la forma b * x^a:")
print(f"a = {popt_pot[0]:.4f}, b = {popt_pot[1]:.4f}")
print("Error: ", error_pot, "\n")

plt.figure(figsize=(10, 6))
plt.scatter(x, y, label='Datos', color='black')
plt.plot(x, y_pred_1, label=f'Grado 1 (Error: {error_1:.2f})')
plt.plot(x, y_pred_2, label=f'Grado 2 (Error: {error_2:.2f})')
plt.plot(x, y_pred_3, label=f'Grado 3 (Error: {error_3:.2f})')
plt.plot(x, y_pred_exp, label=f'Exp (Error: {error_exp:.2f})')
plt.plot(x, y_pred_pot, label=f'Pot (Error: {error_pot:.2f})')

plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid()
plt.title('Ajustes por mínimos cuadrados')
plt.show()
# Out:
# Polinomio de grado 1:
#
# 71.61 x - 191.6
# Error:  105.88388862638901
#
# Polinomio de grado 2:
#         2
# 8.217 x - 19.31 x + 51
# Error:  55.16562001170238
#
# Polinomio de grado 3:
#          3         2
# -2.607 x + 51.56 x - 254.9 x + 469.2
# Error:  51.83830647403031
#
# Polinomio de la forma b * exp(a * x):
# a = 0.3549, b = 26.8408
# Error:  74.36215913505346
#
# Polinomio de la forma b * x^a:
# a = 2.0152, b = 6.2840
# Error:  57.25817542056742

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

x = np.array([0.2, 0.3, 0.6, 0.9, 1.1, 1.3, 1.4, 1.6])
y = np.array([0.050446, 0.098426, 0.33277, 0.72660, 1.0972, 1.5697, 1.8487, 2.5015])

def calcular_error(y_real, y_pred):
    return np.mean((y_real - y_pred) ** 2)

coef_1 = np.polyfit(x, y, 1)
pol_1 = np.poly1d(coef_1)
y_pred_1 = pol_1(x)
error_1 = calcular_error(y, y_pred_1)

coef_2 = np.polyfit(x, y, 2)
pol_2 = np.poly1d(coef_2)
y_pred_2 = pol_2(x)
error_2 = calcular_error(y, y_pred_2)

coef_3 = np.polyfit(x, y, 3)
pol_3 = np.poly1d(coef_3)
y_pred_3 = pol_3(x)
error_3 = calcular_error(y, y_pred_3)

def modelo_exp(x, a, b):
    return b * np.exp(a * x)

popt_exp, _ = curve_fit(modelo_exp, x, y, maxfev=10000)
y_pred_exp = modelo_exp(x, *popt_exp)
error_exp = calcular_error(y, y_pred_exp)

def modelo_pot(x, a, b):
    return b * x**a

popt_pot, _ = curve_fit(modelo_pot, x, y, maxfev=10000)
y_pred_pot = modelo_pot(x, *popt_pot)
error_pot = calcular_error(y, y_pred_pot)

print("Polinomio de grado 1:\n", pol_1)
print("Error: ", error_1, "\n")

print("Polinomio de grado 2:\n", pol_2)
print("Error: ", error_2, "\n")

print("Polinomio de grado 3:\n", pol_3)
print("Error: ", error_3, "\n")

print("Polinomio de la forma b * exp(a * x):")
print(f"a = {popt_exp[0]:.4f}, b = {popt_exp[1]:.4f}")
print("Error: ", error_exp, "\n")

print("Polinomio de la forma b * x^a:")
print(f"a = {popt_pot[0]:.4f}, b = {popt_pot[1]:.4f}")
print("Error: ", error_pot, "\n")

plt.figure(figsize=(10, 6))
plt.scatter(x, y, label='Datos', color='black')
plt.plot(x, y_pred_1, label=f'Grado 1 (Error: {error_1:.2f})')
plt.plot(x, y_pred_2, label=f'Grado 2 (Error: {error_2:.2f})')
plt.plot(x, y_pred_3, label=f'Grado 3 (Error: {error_3:.2f})')
plt.plot(x, y_pred_exp, label=f'Exp (Error: {error_exp:.2f})')
plt.plot(x, y_pred_pot, label=f'Pot (Error: {error_pot:.2f})')

plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid()
plt.title('Ajustes por mínimos cuadrados')
plt.show()
# Out:
# Polinomio de grado 1:
#
# 1.666 x - 0.5125
# Error:  0.041948731969935996
#
# Polinomio de grado 2:
#         2
# 1.129 x - 0.3114 x + 0.08514
# Error:  0.0003024893661783399
#
# Polinomio de grado 3:
#          3          2
# 0.2662 x + 0.4029 x + 0.2484 x - 0.0184
# Error:  6.343339444535476e-07
#
# Polinomio de la forma b * exp(a * x):
# a = 1.8583, b = 0.1326
# Error:  0.008498467250191457
#
# Polinomio de la forma b * x^a:
# a = 2.1428, b = 0.9055
# Error:  0.00043594151427458333

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

x = np.array([28, 25, 28, 27, 28, 33, 28, 29, 23, 27, 29, 28, 27, 29, 21, 28, 28, 26, 30, 24])
y = np.array([3.84, 3.21, 3.23, 3.63, 3.75, 3.20, 3.41, 3.38, 3.53, 2.03, 3.75, 3.65, 3.87, 3.75, 1.66, 3.12, 2.96, 2.92, 3.10, 2.81])

def calcular_error(y_real, y_pred):
    return np.mean((y_real - y_pred) ** 2)

coef_1 = np.polyfit(x, y, 1)
pol_1 = np.poly1d(coef_1)
y_pred_1 = pol_1(x)
error_1 = calcular_error(y, y_pred_1)

print("Polinomio de grado 1 (recta):\n", pol_1)
print("Error: ", error_1, "\n")

plt.figure(figsize=(10, 6))
plt.scatter(x, y, label='Datos', color='black')
plt.plot(x, y_pred_1, label=f'Recta (Error: {error_1:.2f})', color='red')

plt.xlabel('Puntuación ACT')
plt.ylabel('Promedio de puntos')
plt.legend()
plt.grid()
plt.title('Ajuste por mínimos cuadrados para Puntuación ACT vs Promedio de puntos')
plt.show()
# Out:
# Polinomio de grado 1 (recta):
#
# 0.1009 x + 0.4866
# Error:  0.2524352808112325

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

x = np.array([4800, 3700, 3400, 2800, 1900])
y = np.array([3.1, 4.0, 5.2, 6.4, 9.6])

def calcular_error(y_real, y_pred):
    return np.mean((y_real - y_pred) ** 2)

coef_1 = np.polyfit(x, y, 1)
pol_1 = np.poly1d(coef_1)
y_pred_1 = pol_1(x)
error_1 = calcular_error(y, y_pred_1)

print("Polinomio de grado 1 (recta):\n", pol_1)
print("Error: ", error_1, "\n")

plt.figure(figsize=(10, 6))
plt.scatter(x, y, label='Datos', color='black')
plt.plot(x, y_pred_1, label=f'Recta (Error: {error_1:.2f})', color='red')

plt.xlabel('Peso promedio (lb)')
plt.ylabel('Porcentaje de presentación')
plt.legend()
plt.grid()
plt.title('Ajuste por mínimos cuadrados para Peso vs Porcentaje de presentación')
plt.show()
# Out:
# Polinomio de grado 1 (recta):
#
# -0.002255 x + 13.15
# Error:  0.4118271391529816
